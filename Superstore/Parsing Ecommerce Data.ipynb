# %% [markdown]
# # Parsing Ecommerce Data

# %% [markdown]
# ### Import required packages

# %%
import pandas as pd
import numpy as np
import os
import glob
import datetime
import pyodbc

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hpind\\Death Analysis  Project\\Superstore'

# %%
path, dirs, files = next(os.walk("C:/Users/hpind/Death Analysis  Project/files/"))

# %%
path
# Out:
# 'C:/Users/hpind/Death Analysis  Project/files/'

# %%
dirs
# Out:
# []

# %%
files
# Out:
# ['Superstore.csv',
#  'Superstore1.csv',
#  'Superstore2.csv',
#  'Superstore3.csv',
#  'Superstore4.csv',
#  'Superstore5.csv',
#  'Superstore6.csv',
#  'Superstore7.csv']

# %%
os.path.join('C:/Users/hpind/Death Analysis  Project/files/','*.csv')
# Out:
# 'C:/Users/hpind/Death Analysis  Project/files/*.csv'

# %%
files_list = glob.glob(os.path.join('C:/Users/hpind/Death Analysis  Project/files/','*.csv'))

# %%
files_list
# Out:
# ['C:/Users/hpind/Death Analysis  Project/files\\Superstore.csv',
#  'C:/Users/hpind/Death Analysis  Project/files\\Superstore1.csv',
#  'C:/Users/hpind/Death Analysis  Project/files\\Superstore2.csv',
#  'C:/Users/hpind/Death Analysis  Project/files\\Superstore3.csv',
#  'C:/Users/hpind/Death Analysis  Project/files\\Superstore4.csv',
#  'C:/Users/hpind/Death Analysis  Project/files\\Superstore5.csv',
#  'C:/Users/hpind/Death Analysis  Project/files\\Superstore6.csv',
#  'C:/Users/hpind/Death Analysis  Project/files\\Superstore7.csv']

# %%
for filespath in files_list:
    print(filespath)
# Out:
# C:/Users/hpind/Death Analysis  Project/files\Superstore.csv
# C:/Users/hpind/Death Analysis  Project/files\Superstore1.csv
# C:/Users/hpind/Death Analysis  Project/files\Superstore2.csv
# C:/Users/hpind/Death Analysis  Project/files\Superstore3.csv
# C:/Users/hpind/Death Analysis  Project/files\Superstore4.csv
# C:/Users/hpind/Death Analysis  Project/files\Superstore5.csv
# C:/Users/hpind/Death Analysis  Project/files\Superstore6.csv
# C:/Users/hpind/Death Analysis  Project/files\Superstore7.csv

# %%
pd.read_csv('C:/Users/hpind/Death Analysis  Project/files//Superstore.csv', encoding ='Windows-1252')
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1         2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2         3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3         4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4         5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ..      ...             ...         ...         ...             ...
# 96       97  CA-2017-161018   11/9/2017  11/11/2017    Second Class
# 97       98  CA-2017-157833   6/17/2017   6/20/2017     First Class
# 98       99  CA-2016-149223    9/6/2016   9/11/2016  Standard Class
# 99      100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# 100     101  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
#
#     Customer ID      Customer Name      Segment        Country  \
# 0      CG-12520        Claire Gute     Consumer  United States
# ...

# %%
pd.read_csv('C:/Users/hpind/Death Analysis  Project/files//Superstore.csv', encoding ='latin1')
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1         2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2         3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3         4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4         5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ..      ...             ...         ...         ...             ...
# 96       97  CA-2017-161018   11/9/2017  11/11/2017    Second Class
# 97       98  CA-2017-157833   6/17/2017   6/20/2017     First Class
# 98       99  CA-2016-149223    9/6/2016   9/11/2016  Standard Class
# 99      100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# 100     101  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
#
#     Customer ID      Customer Name      Segment        Country  \
# 0      CG-12520        Claire Gute     Consumer  United States
# ...

# %%
for filespath in files_list:
    filespath = filespath.replace('\\','/')
     print(filespath)
# Out:
#   Input In [33]
#     print(filespath)
#     ^
# IndentationError: unexpected indent

# %%
Final_Data = pd.DataFrame()
for filespath in files_list:
    filespath = filespath.replace('\\','/')
    df = pd.read_csv(filespath, encoding ='Windows-1252')
    df.columns = df.columns.str.strip().str.replace (' ','_')
    df.drop('Row_ID' , axis = 1,inplace =True)
    df.drop_duplicates(keep = 'first',inplace = True)
    Final_Data = Final_Data.append(df)
# Out:
# C:\Users\hpind\AppData\Local\Temp\ipykernel_18392\4086935541.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Final_Data = Final_Data.append(df)
# C:\Users\hpind\AppData\Local\Temp\ipykernel_18392\4086935541.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Final_Data = Final_Data.append(df)
# C:\Users\hpind\AppData\Local\Temp\ipykernel_18392\4086935541.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Final_Data = Final_Data.append(df)
# C:\Users\hpind\AppData\Local\Temp\ipykernel_18392\4086935541.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Final_Data = Final_Data.append(df)
# ...

# %%
Final_Data.shape
# Out:
# (12995, 20)

# %%
df = pd.read_csv('C:/Users/hpind/Death Analysis  Project/files//Superstore.csv', encoding ='Windows-1252')
df.columns. str.strip().str.replace (' ','_')
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
Final_Data.head()
# Out:
#          Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal_Code Region       Product_ID         Category Sub-Category  \
# ...

# %%
Final_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12995 entries, 0 to 1093
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       12995 non-null  object
#  1   Order_Date     12995 non-null  object
#  2   Ship_Date      12995 non-null  object
#  3   Ship_Mode      12995 non-null  object
#  4   Customer_ID    12995 non-null  object
#  5   Customer_Name  12995 non-null  object
#  6   Segment        12995 non-null  object
#  7   Country        12995 non-null  object
#  8   City           12995 non-null  object
#  9   State          12995 non-null  object
#  10  Postal_Code    12995 non-null  int64
#  11  Region         12995 non-null  object
#  12  Product_ID     12995 non-null  object
#  13  Category       12995 non-null  object
#  14  Sub-Category   12995 non-null  object
#  15  Product_Name   12995 non-null  object
#  16  Sales          12995 non-null  float64
# ...

# %%
Final_Data.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
Final_Data.boxplot()
# Out:
# <AxesSubplot:>

# %%
Final_Data
# Out:
#             Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 1089  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 1090  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 1091  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 1092  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 1093  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#          Customer_Name    Segment        Country             City       State  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         101 non-null    int64
#  1   Order ID       101 non-null    object
#  2   Order Date     101 non-null    object
#  3   Ship Date      101 non-null    object
#  4   Ship Mode      101 non-null    object
#  5   Customer ID    101 non-null    object
#  6   Customer Name  101 non-null    object
#  7   Segment        101 non-null    object
#  8   Country        101 non-null    object
#  9   City           101 non-null    object
#  10  State          101 non-null    object
#  11  Postal Code    101 non-null    int64
#  12  Region         101 non-null    object
#  13  Product ID     101 non-null    object
#  14  Category       101 non-null    object
#  15  Sub-Category   101 non-null    object
#  16  Product Name   101 non-null    object
# ...

# %%
df.max()
# Out:
# Row ID                                          101
# Order ID                             US-2017-156909
# Order Date                                 9/6/2016
# Ship Date                                  9/8/2015
# Ship Mode                            Standard Class
# Customer ID                                ZD-21925
# Customer Name                    Zuschuss Donatelli
# Segment                                 Home Office
# Country                               United States
# City                                       Westland
# State                                     Wisconsin
# Postal Code                                   98103
# Region                                         West
# Product ID                          TEC-PH-10004977
# Category                                 Technology
# Sub-Category                                 Tables
# Product Name     netTALK DUO VoIP Telephone Service
# Sales                                       3083.43
# ...

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.columns= [i for i in df.columns]

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.columns. str.strip().str.replace (' ','_')
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
 df.columns = df.columns. str.strip().str.replace (' ','_')

# %%
 df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df = pd.read_csv('C:/Users/hpind/Death Analysis  Project/files//Superstore.csv', encoding ='Windows-1252')
df.columns = df.columns.str.strip().str.replace (' ','_')
df.drop('Row_ID' , axis = 1,inplace =True)
df.drop_duplicates(keep = 'first',inplace = True)

# %%
df.head(5)
# Out:
#          Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal_Code Region       Product_ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (101, 20)

# %%
df.drop('Row_ID' , axis = 1,inplace =True)

# %%
df
# Out:
#            Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0    CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1    CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2    CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3    US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4    US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ..              ...         ...         ...             ...         ...
# 96   CA-2017-161018   11/9/2017  11/11/2017    Second Class    PN-18775
# 97   CA-2017-157833   6/17/2017   6/20/2017     First Class    KD-16345
# 98   CA-2016-149223    9/6/2016   9/11/2016  Standard Class    ER-13855
# 99   CA-2016-158568   8/29/2016    9/2/2016  Standard Class    RB-19465
# 100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class    RB-19465
#
#          Customer_Name      Segment        Country             City  \
# ...

# %%
df.drop_duplicates(keep = 'first',inplace = True)

# %%
df
# Out:
#            Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0    CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1    CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2    CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3    US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4    US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ..              ...         ...         ...             ...         ...
# 96   CA-2017-161018   11/9/2017  11/11/2017    Second Class    PN-18775
# 97   CA-2017-157833   6/17/2017   6/20/2017     First Class    KD-16345
# 98   CA-2016-149223    9/6/2016   9/11/2016  Standard Class    ER-13855
# 99   CA-2016-158568   8/29/2016    9/2/2016  Standard Class    RB-19465
# 100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class    RB-19465
#
#          Customer_Name      Segment        Country             City  \
# ...

# %%
customer_df = Final_Data[['Customer_ID','Customer_Name','Segment']]
customer_df = customer_df.drop_duplicates(keep = 'first')

# %%
customer_df.head()
# Out:
#    Customer_ID    Customer_Name    Segment
# 0     CG-12520      Claire Gute   Consumer
# 2     DV-13045  Darrin Van Huff  Corporate
# 3     SO-20335   Sean O'Donnell   Consumer
# 5     BH-11710  Brosina Hoffman   Consumer
# 12    AA-10480     Andrew Allen   Consumer

# %%
customer_df.duplicated()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1089     True
# 1090     True
# 1091     True
# 1092     True
# 1093     True
# Length: 12995, dtype: bool

# %%
customer_df.nunique()
# Out:
# Customer_ID      793
# Customer_Name    793
# Segment            3
# dtype: int64

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12995 entries, 0 to 1093
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    12995 non-null  object
#  1   Customer_Name  12995 non-null  object
#  2   Segment        12995 non-null  object
# dtypes: object(3)
# memory usage: 406.1+ KB

# %%
customer_df['Customer_Name'].value_counts()
# Out:
# Claire Gute          1
# Henia Zydlo          1
# Jamie Kunitz         1
# Filia McAdams        1
# Emily Ducich         1
#                     ..
# Ralph Arnett         1
# Naresj Patel         1
# Alan Barnes          1
# Jesus Ocampo         1
# Susan MacKendrick    1
# Name: Customer_Name, Length: 793, dtype: int64

# %%
customer_df = customer_df.drop_duplicates(keep = 'first')

# %%
customer_df.shape
# Out:
# (793, 3)
