# %%
#what is web scraping?

# %% [markdown]
# #Web scraping is an automated method used to extract large amounts of data from websites. The data on the websites are unstructured. Web scraping helps collect these unstructured data and store it in a structured form. There are different ways to scrape websites such as online Services, APIs or writing your own code.

# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
import lxml

# %%
#!pip install bs4

# %%
#!pip install requests

# %%
#!pip install lxml

# %%
response = requests.get('https://www.flipkart.com/search?q=ecommerce%20book&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off')

# %%
response
# Out:
# <Response [200]>

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %%
response.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
# Soup = BeautifulSoup(response.text,'lxml')
Soup = BeautifulSoup(response.text )

# %%
Soup
# Out:
# <!DOCTYPE html>
# ...

# %%
Ebook_list = Soup.select('a.s1Q9rs')

# %%
Ebook_list =[a.text for a in Soup.select('a.s1Q9rs')]

# %%
Ebook_list
# Out:
# ['The Business of Ecommerce',
#  'E-Commerce',
#  'eCommerce Marketing',
#  'Ecommerce Millionaires',
#  'Ecommerce',
#  'eCommerce MasterPlan 1.8',
#  'Design and Launch an eCommerce Business in a Week',
#  'Beginners Guide to Building Ecommerce Websites With Wor...',
#  'Designing Personalized User Experiences in eCommerce',
#  'ECOMMERCE IN THE CLOUD',
#  'Understanding & Implementing Ecommerce PB',
#  'Web Technology and Ecommerce',
#  'HCI in Business, Government and Organizations. eCommerc...',
#  'Advances in Digital Marketing and eCommerce',
#  'Advances in Digital Marketing and eCommerce',
#  'eBusiness & eCommerce',
#  'eBusiness & eCommerce',
#  'Successful Social Media and Ecommerce Strategies in the...',
#  'Plattformoekonomie Und Ecommerce Im Banking',
#  'ECOMMERCE BUSINESS MARKETING 2022',
#  'Technology How Influences Ecommerce Market Development',
#  'Ecommerce Leisure Business Development',
#  'ESSENTIALS OF ECOMMERCE MARKETING',
# ...

# %%
len(Ebook_list)
# Out:
# 40

# %%
type(Ebook_list)
# Out:
# list

# %%
Ebook_Name = pd.DataFrame(columns=['Book_Name'])
for i in range (len(Ebook_list)):
    Ebook_Name = Ebook_list[i]
    dlist = {}
    E_book_Name = pd.DataFrame(columns=['Book_Name'])
    dlist['Book_Name'] = Ebook_Name
    E_book_Name = Ebook_Name.append(dlist,ignore_inplace=True)
    Ebook_Name = Ebook_Name.append(E_book_Name,ignore_inplace =True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       5 E_book_Name = pd.DataFrame(columns=['Book_Name'])
#       6 dlist['Book_Name'] = Ebook_Name
# ----> 7 E_book_Name = Ebook_Name.append(dlist,ignore_inplace=True)
#       8 Ebook_Name = Ebook_Name.append(E_book_Name,ignore_inplace =True)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
Ebook_Name

# %%
Ebook_Name
# Out:
# Empty DataFrame
# Columns: [Book_Name]
# Index: []

# %%
for i in range(0,len(Ebook_list)):
    df= pd.DataFrame(columns=['Movie_Name'])
    dlist={}
    m_string = Ebook_list[i].get_text()
    m =  ' '.join(m_string.split()).replace('.' , '')
    Ebook_name = m[len(str(i)) + 1:-7:]
    year = re.search('\((.*?)\)',m).group(1)
    director = movie_title[i]
    ratings = round(float(rating[i]),1)
    s = votes[i][13:len(votes[i])-13:].replace(',','')
    voting = int (s)
    movies_details_link = movie_links[i]
    dlist['movie_Name'] = movie_name
    dlist['Movie_details_Link'] = movies_details_link
    temp_df = df.append(dlist,ignore_index = True)
    Final_movies = Final_movies.append(temp_df)

# %%
# Out:
# ['9.235282542546296',
#  '9.155954600369704',
#  '8.990152880244716',
#  '8.984057785108915',
#  '8.951664196255347',
#  '8.93887862053532',
#  '8.93021848352174',
#  '8.847743940415215',
#  '8.809776576446161',
#  '8.790163898052246',
#  '8.76734980016152',
#  '8.74844192728586',
#  '8.735082379310393',
#  '8.733016100354105',
#  '8.699223208377951',
#  '8.66952957429571',
#  '8.652590645334206',
#  '8.63889614556023',
#  '8.604275164486952',
#  '8.598685405849839',
#  '8.59774302246678',
#  '8.588075693908127',
#  '8.579647838435706',
#  '8.579251576861887',
#  '8.56836428639847',
#  '8.567314597725158',
#  '8.562617538614667',
#  '8.549419248904695',
#  '8.537188522454048',
#  '8.517909726401252',
#  '8.516133542414458',
#  '8.50687356304381',
#  '8.506831603510618',
#  '8.498836023631426',
#  '8.494977067309668',
#  '8.488100475658241',
#  '8.486399027271473',
#  '8.482335606835022',
#  '8.475978783549769',
#  '8.471065070013514',
#  '8.468994533057081',
#  '8.466493556252473',
# ...

# %%
movie_list[2]
# Out:
# <td class="titleColumn">
#       3.
#       <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
# <span class="secondaryInfo">(2008)</span>
# </td>

# %%
movie_list[0].get_text()
# Out:
# '\n      1.\n      The Shawshank Redemption\n(1994)\n'

# %%
s = s.strip()

# %%
s.split('\n')
# Out:
# ['2684217']

# %%
movie_name
# Out:
# 'The Shawshank Redemption'

# %%
for i in range(len(movie_list)):
    s= movie_list[i].get_text()
    s = s.strip()
    s=s.split('\n')
    movie_name = s[1].strip()
    ryear = s[2].strip()
    year = re.search('\((.*?)\)',ryear).group(1)
    director = movie_title[i]
    userrating =  rating[i]
    voting = int(votes[i].split()[3].replace(',',''))
    mlink = movie_links [i]

# %%
len(movie_list)
# Out:
# 250

# %%
movie_title[2]
# Out:
# 'Christopher Nolan (dir.), Christian Bale, Heath Ledger'

# %%
 rating
# Out:
# ['9.235282542546296',
#  '9.155954600369704',
#  '8.990152880244716',
#  '8.984057785108915',
#  '8.951664196255347',
#  '8.93887862053532',
#  '8.93021848352174',
#  '8.847743940415215',
#  '8.809776576446161',
#  '8.790163898052246',
#  '8.76734980016152',
#  '8.74844192728586',
#  '8.735082379310393',
#  '8.733016100354105',
#  '8.699223208377951',
#  '8.66952957429571',
#  '8.652590645334206',
#  '8.63889614556023',
#  '8.604275164486952',
#  '8.598685405849839',
#  '8.59774302246678',
#  '8.588075693908127',
#  '8.579647838435706',
#  '8.579251576861887',
#  '8.56836428639847',
#  '8.567314597725158',
#  '8.562617538614667',
#  '8.549419248904695',
#  '8.537188522454048',
#  '8.517909726401252',
#  '8.516133542414458',
#  '8.50687356304381',
#  '8.506831603510618',
#  '8.498836023631426',
#  '8.494977067309668',
#  '8.488100475658241',
#  '8.486399027271473',
#  '8.482335606835022',
#  '8.475978783549769',
#  '8.471065070013514',
#  '8.468994533057081',
#  '8.466493556252473',
# ...

# %%
for i in range(len(movie_list)):
    s= movie_list[i].get_text()
    s = s.strip()
    s=s.split('\n')
    movie_name = s[1].strip()
    ryear = s[2].strip()
    year = re.search('\((.*?)\)',ryear).group(1)
    director = movie_title[i]
    userrating =  rating[i]
    voting = int(votes[i].split()[3].replace(',',''))
    mlink = movie_links [i]

# %%
Final_movies = pd.DataFrame(columns=['Movie_Name','Released_year','Director',
                                    'movie_Rating','User_voting','Movie_details_Link'])
for i in range(0,len(movie_list)):
    df= pd.DataFrame(columns=['Movie_Name','Released_year','Director',
                                    'movie_Rating','User_voting','Movie_details_Link'])
    dlist={}
    m_string = movie_list[i].get_text()
    m =  ' '.join(m_string.split()).replace('.' , '')
    movie_name = m[len(str(i)) + 1:-7:]
    year = re.search('\((.*?)\)',m).group(1)
    director = movie_title[i]
    ratings = round(float(rating[i]),1)
    s = votes[i][13:len(votes[i])-13:].replace(',','')
    voting = int (s)
    movies_details_link = movie_links[i]
    dlist['movie_Name'] = movie_name
    dlist['Released_Year']= year
    dlist['Director'] = director
    dlist['Movie_Rating'] = ratings
    dlist['User_voting']= voting
    dlist['Movie_details_Link'] = movies_details_link
    temp_df = df.append(dlist,ignore_index = True)
    Final_movies = Final_movies.append(temp_df)
# Out:
# C:\Users\hpind\AppData\Local\Temp\ipykernel_6636\3416519120.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df = df.append(dlist,ignore_index = True)
# C:\Users\hpind\AppData\Local\Temp\ipykernel_6636\3416519120.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Final_movies = Final_movies.append(temp_df)
# C:\Users\hpind\AppData\Local\Temp\ipykernel_6636\3416519120.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df = df.append(dlist,ignore_index = True)
# C:\Users\hpind\AppData\Local\Temp\ipykernel_6636\3416519120.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
Final_movies
# Out:
#    Movie_Name Released_year  \
# 0         NaN           NaN
# 0         NaN           NaN
# 0         NaN           NaN
# 0         NaN           NaN
# 0         NaN           NaN
# ..        ...           ...
# 0         NaN           NaN
# 0         NaN           NaN
# 0         NaN           NaN
# 0         NaN           NaN
# 0         NaN           NaN
#
#                                              Director movie_Rating  \
# 0   Frank Darabont (dir.), Tim Robbins, Morgan Fre...          NaN
# 0   Francis Ford Coppola (dir.), Marlon Brando, Al...          NaN
# 0   Christopher Nolan (dir.), Christian Bale, Heat...          NaN
# 0   Francis Ford Coppola (dir.), Al Pacino, Robert...          NaN
# 0       Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb          NaN
# ..                                                ...          ...
# 0   Brad Bird (dir.), Eli Marienthal, Harry Connic...          NaN
# 0         Tate Taylor (dir.), Viola Davis, Emma Stone          NaN
# ...

# %%
Final_movies
# Out:
#      index Movie_Name Released_year  \
# 0        0        NaN           NaN
# 1        0        NaN           NaN
# 2        0        NaN           NaN
# 3        0        NaN           NaN
# 4        0        NaN           NaN
# ..     ...        ...           ...
# 245      0        NaN           NaN
# 246      0        NaN           NaN
# 247      0        NaN           NaN
# 248      0        NaN           NaN
# 249      0        NaN           NaN
#
#                                               Director movie_Rating  \
# 0    Frank Darabont (dir.), Tim Robbins, Morgan Fre...          NaN
# 1    Francis Ford Coppola (dir.), Marlon Brando, Al...          NaN
# 2    Christopher Nolan (dir.), Christian Bale, Heat...          NaN
# 3    Francis Ford Coppola (dir.), Al Pacino, Robert...          NaN
# 4        Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb          NaN
# ..                                                 ...          ...
# ...

# %%
Final_movies = Final_movies.drop(['index'],axis = 1)

# %%
Final_movies
# Out:
#      level_0 Movie_Name Released_year  \
# 0          0        NaN           NaN
# 1          1        NaN           NaN
# 2          2        NaN           NaN
# 3          3        NaN           NaN
# 4          4        NaN           NaN
# ..       ...        ...           ...
# 245      245        NaN           NaN
# 246      246        NaN           NaN
# 247      247        NaN           NaN
# 248      248        NaN           NaN
# 249      249        NaN           NaN
#
#                                               Director movie_Rating  \
# 0    Frank Darabont (dir.), Tim Robbins, Morgan Fre...          NaN
# 1    Francis Ford Coppola (dir.), Marlon Brando, Al...          NaN
# 2    Christopher Nolan (dir.), Christian Bale, Heat...          NaN
# 3    Francis Ford Coppola (dir.), Al Pacino, Robert...          NaN
# 4        Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb          NaN
# ..                                                 ...          ...
# ...

# %%
Final_movies.to_csv('Movie_Data.csv')

# %%
Final_movies.to_excel('Movie_Data.xlsx')
